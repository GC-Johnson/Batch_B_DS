# %%
#1#
name = "Gideon Chizunem Johnson"
print(name)
# Out:
# Gideon Chizunem Johnson

# %%
#2#
num1, num2 = 25, 10
addition, diffrence, product, quotient = num1 + num2, num1 - num2, num1 * num2, num1 / num2
print(f"{addition} is the sum result. {diffrence} is the diffrence result. {product} is the product result. {quotient} is the quotient result." )
# Out:
# 35 is the sum result. 15 is the diffrence result. 250 is the product result. 2.5 is the quotient result.

# %%
#3#
price, quantity = 2500, 7
total_cost = price * quantity
total = total_cost
print(total, 'is the total of what you are to pay for! ')
# Out:
# 17500 is the total of what you are to pay for!

# %%
#4#
length, width = 15, 9
area = int(length * width)
print(area, "is the 'area' of the rectangle.")
# Out:
# 135 is the 'area' of the rectangle.

# %%
#5#
student_score = [78,82,65,90,75]
print(sum(student_score), "is the total score. ", (sum(student_score))/5, "is the average" )
# Out:
# 390 is the total score.  78.0 is the average

# %%
#6#
num3, num4 = 47, 6
quotient_remainder = num3%num4
print(quotient_remainder)
# Out:
# 5

# %%
#7#
result = 5**4
print(result)
# Out:
# 625

# %%
#8#
product_cost, discount = 8500, 20
discount_amount = (20/100)*8500
final_price = discount_amount
print(final_price, "is the final price")
# Out:
# 1700.0 is the final price

# %%
#9#
total_minutes = 156
hours, minutes_remain = total_minutes//60, total_minutes%60
#minutes_remain = total_minutes%60
print(hours,"hour(s)", minutes_remain,"min(s)")
# Out:
# 2 hour(s) 36 min(s)

# %%
#10#
car_travel_in_kilimeter, hour_travel = 240, 3
speed_in_kilometers_per_hour = car_travel_in_kilimeter/hour_travel
print(speed_in_kilometers_per_hour, "kilometers per hour")
# Out:
# 80.0 kilometers per hour
